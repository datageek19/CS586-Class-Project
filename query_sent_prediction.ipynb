# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import numpy
import csv

# %%
with open('train.pair_tok.tsv', encoding='utf-8') as f:
    sentences = csv.reader(f)
    for sentence in sentences:
        vectorizer = TfidfVectorizer(stop_words="english")
        X = vectorizer.fit_transform(sentence)
        words = vectorizer.get_feature_names()
        print("words", words)
# Out:
# words ['actor', 'appeared_in_tv_program', 'e1', 'general', 'hospital', 'playing', 'regular_tv_appearance', 'tv', 'tv_character']
# words ['actor', 'e1', 'film', 'movies', 'performance']
# words ['american_football', 'current_team', 'does', 'e1', 'football_player', 'play', 'sports', 'sports_team_roster', 'team']
# words ['award', 'award_nomination', 'award_nominations', 'award_nominee', 'e1', 'married']
# words ['actor', 'character', 'e1', 'film', 'performance', 'soul', 'surfer']
# words ['did', 'e1', 'education', 'institution', 'people', 'person', 'university']
# words ['did', 'e1', 'inventions', 'inventor', 'law', 'make']
# words ['cvg', 'e1', 'family', 'game_character', 'game_performance', 'games', 'guy', 'voice', 'voice_actor']
# words ['county', 'e1', 'transport_terminus', 'transportation', 'travel', 'travel_destination', 'travel_destinations_served']
# words ['2011', 'does', 'e1', 'football_roster_position', 'play', 'pro_athlete', 'soccer', 'sports', 'team', 'teams']
# words ['did', 'e1', 'pro_athlete', 'sign', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['actor', 'appeared_in_tv_program', 'e1', 'family', 'guy', 'plays', 'regular_tv_appearance', 'tv', 'tv_character', 'voice']
# words ['celtics', 'did', 'drafted', 'drafted_athlete', 'e1', 'play', 'sports', 'sports_league_draft_pick', 'team']
# words ['basketball', 'basketball_historical_roster_position', 'does', 'e1', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['e1', 'inventions', 'inventor', 'law']
# words ['did', 'e1', 'human_language', 'language', 'live', 'main_country']
# words ['actor', 'e1', 'film', 'film_character', 'menace', 'performance', 'phantom', 'played', 'portrayed_in_films']
# words ['e1', 'government', 'president', 'succeeded', 'us_president', 'vice_president']
# words ['base', 'celebrity', 'e1', 'husband', 'infidelity', 'infidelity_perpetrator', 'participant', 'popstra']
# words ['citytown', 'e1', 'headquarters', 'located', 'location', 'mailing_address', 'organization']
# words ['containedby', 'e1', 'located', 'location', 'map']
# words ['base', 'born', 'celebrity', 'e1', 'location', 'popstra', 'state', 'vacation_choice', 'vacations_in']
# words ['athlete_extra', 'athlete_salary', 'base', 'did', 'e1', 'salary', 'schemastaging', 'sign', 'team']
# words ['containedby', 'e1', 'florida', 'location', 'map']
# words ['actor', 'appeared_in_tv_program', 'e1', 'looney', 'regular_tv_appearance', 'tunes', 'tv', 'tv_character', 'voices']
# words ['airport', 'close', 'e1', 'location', 'nearby_airports']
# words ['e1', 'greek', 'name_source', 'namesakes', 'symbols']
# words ['did', 'direct', 'e1', 'film', 'movie', 'producer']
# words ['e1', 'location', 'time', 'time_zones', 'zone']
# words ['did', 'died', 'e1', 'live', 'people', 'person', 'place_of_birth']
# words ['awards', 'did', 'e1', 'play', 'season', 'sports', 'sports_award', 'sports_award_winner', 'years']
# words ['did', 'e1', 'ethnicity', 'included_in_group', 'indians', 'live', 'people']
# words ['adjoin_s', 'adjoining_relationship', 'adjoins', 'borders', 'countries', 'e1', 'location', 'share']
# words ['countries', 'e1', 'human_language', 'language', 'main_country', 'native']
# words ['e1', 'founded', 'sports', 'sports_team', 'year']
# words ['attend', 'college', 'did', 'e1', 'education', 'institution', 'people', 'person']
# words ['e1', 'film', 'film_subject', 'films']
# words ['belong', 'did', 'e1', 'government', 'party', 'political_party_tenure', 'politician']
# words ['bowls', 'championships', 'e1', 'sports', 'sports_team', 'super', 'won']
# words ['e1', 'leadership', 'organization', 'person', 'started']
# words ['e1', 'tourist_attractions', 'travel', 'travel_destination', 'week']
# words ['administrative_division', 'administrative_division_capital_relationship', 'capital', 'e1', 'location', 'scorpions']
# words ['e1', 'nationality', 'people', 'person', 'queen']
# words ['country', 'e1', 'kind', 'language', 'location', 'official_language', 'speak']
# words ['actor', 'appeared_in_tv_episodes', 'e1', 'plays', 'supernatural', 'tv', 'tv_character', 'tv_guest_role', 'young']
# words ['basketball', 'basketball_roster_position', 'did', 'e1', 'pro_athlete', 'sign', 'sports', 'team', 'teams']
# words ['country', 'does', 'e1', 'location', 'official_language', 'people', 'speak']
# words ['e1', 'father', 'fictional_character', 'fictional_universe', 'jr', 'parents']
# words ['battle', 'capital', 'country', 'did', 'e1', 'location', 'surrender', 'ww2']
# words ['administrative_division', 'country', 'e1', 'located', 'location']
# words ['college', 'did', 'drafted', 'drafted_athlete', 'e1', 'school', 'sports', 'sports_league_draft_pick']
# words ['awards', 'e1', 'played', 'sports', 'sports_award', 'sports_award_winner', 'team']
# words ['country', 'does', 'e1', 'form', 'form_of_government', 'government', 'location']
# words ['championships', 'did', 'e1', 'pennant', 'sports', 'sports_team', 'win']
# words ['appointed_by', 'appointee', 'appointment', 'e1', 'nominated', 'people', 'position']
# words ['art', 'associated_periods_or_movements', 'e1', 'involved', 'movements', 'visual_art', 'visual_artist']
# words ['containedby', 'e1', 'location', 'state']
# words ['boyfriend', 'character_created_by', 'e1', 'fictional_character', 'fictional_universe', 'played', 'seinfeld']
# words ['celebrities', 'celebrity', 'did', 'e1', 'love', 'really', 'romantic_relationship', 'sexual_relationships']
# words ['base', 'belong', 'biblioness', 'bibs_location', 'country', 'does', 'e1']
# words ['actor', 'appeared_in_tv_program', 'e1', 'family', 'guy', 'plays', 'regular_tv_appearance', 'tv', 'tv_character']
# words ['country', 'e1', 'language', 'languages_spoken', 'location', 'primary']
# words ['did', 'e1', 'factor', 'seasons', 'tv', 'tv_personality', 'tv_regular_appearances', 'tv_regular_personal_appearance', 'won']
# words ['believe', 'collective_term_for_adherents', 'e1', 'religion']
# words ['country', 'e1', 'language', 'languages_spoken', 'location', 'speak']
# words ['attend', 'did', 'e1', 'education', 'institution', 'people', 'person', 'school']
# words ['appointees', 'countries', 'did', 'e1', 'government', 'government_position_held', 'jurisdiction_of_office', 'political_appointer', 'rule']
# words ['currency', 'dated_money_value', 'does', 'e1', 'gni_per_capita_in_ppp_dollars', 'location', 'measurement_unit', 'statistical_region', 'type']
# words ['country', 'currency', 'currency_used', 'e1', 'kind', 'location', 'use']
# words ['ameroamigo', 'default_domain', 'did', 'e1', 'federal_reserve_bank', 'federal_reserve_region', 'hit', 'tornado', 'user']
# words ['band', 'does', 'e1', 'group', 'group_member', 'group_membership', 'membership', 'music', 'sing']
# words ['country', 'e1', 'language', 'languages_spoken', 'location', 'speak']
# words ['born', 'e1', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['containedby', 'e1', 'located', 'location']
# words ['e1', 'marriage', 'married', 'people', 'person', 'spouse', 'spouse_s']
# words ['did', 'e1', 'evolution', 'mechanism', 'people', 'person', 'propose', 'quotations']
# words ['architecture', 'building', 'building_complex', 'e1', 'located']
# words ['actor', 'appeared_in_tv_program', 'e1', 'plays', 'regular_tv_appearance', 'skins', 'tv', 'tv_character', 'uk']
# words ['author', 'book', 'conducted', 'did', 'e1', 'experiments', 'works_written']
# words ['countries', 'deceased_person', 'did', 'e1', 'people', 'place_of_death', 'work']
# words ['county', 'e1', 'hud_county_place', 'location', 'ohio']
# words ['artist', 'born', 'city', 'e1', 'music', 'origin']
# words ['2012', 'base', 'current_club', 'current_world_cup_squad', 'does', 'e1', 'play', 'world_cup_participant', 'world_cup_team', 'x2010fifaworldcupsouthafrica']
# words ['american_football', 'does', 'e1', 'football_roster_position', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['art', 'art_forms', 'does', 'e1', 'type', 'visual_art', 'visual_artist']
# words ['base', 'did', 'e1', 'famouspets', 'marry', 'owner', 'pet_owner', 'pet_ownership', 'pets_owned']
# words ['buried', 'deceased_person', 'e1', 'people', 'place_of_death']
# words ['does', 'e1', 'pro_athlete', 'pro_sports_played', 'race', 'sport', 'sports', 'sports_played_professionally', 'tonight']
# words ['actor', 'character', 'crazy', 'e1', 'film', 'love', 'performance', 'stupid']
# words ['basketball', 'basketball_roster_position', 'current', 'e1', 'player', 'roster', 'sports', 'sports_team']
# words ['degree', 'does', 'e1', 'education', 'major_field_of_study', 'people', 'person']
# words ['actor', 'e1', 'film', 'film_character', 'movies', 'performance', 'played', 'portrayed_in_films', 'star', 'wars']
# words ['championships', 'did', 'e1', 'series', 'sports', 'sports_team', 'win', 'world', 'year']
# words ['did', 'direct', 'e1', 'regular_tv_appearance', 'series', 'starring_roles', 'tv', 'tv_actor']
# words ['actor', 'appeared_in_tv_episodes', 'buffy', 'e1', 'plays', 'slayer', 'tv', 'tv_character', 'tv_guest_role', 'vampire']
# words ['e1', 'location', 'people', 'person', 'place_lived', 'places_lived', 'tomb']
# words ['did', 'e1', 'grow', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['country', 'e1', 'nationality', 'people', 'person']
# words ['born', 'e1', 'emperor', 'people', 'person', 'place_of_birth']
# words ['e1', 'football_roster_position', 'played', 'pro_athlete', 'soccer', 'sports', 'team', 'teams']
# words ['capital', 'cherry', 'country', 'e1', 'grow', 'location', 'trees']
# words ['containedby', 'e1', 'located', 'location']
# words ['american_football', 'did', 'e1', 'football_player', 'leave', 'passing', 'player_passing_statistics', 'season', 'usc']
# words ['cause_of_death', 'deceased_person', 'did', 'die', 'e1', 'people']
# words ['e1', 'location', 'recognized', 'religion', 'religion_percentage', 'religions', 'statistical_region']
# words ['country', 'current', 'e1', 'form_of_government', 'government', 'location']
# words ['24', 'clock', 'e1', 'hour', 'location', 'time', 'time_zones']
# words ['baby', 'children', 'e1', 'girls', 'people', 'person']
# words ['basketball', 'basketball_team', 'current', 'e1', 'player', 'roster', 'sports', 'sports_team_roster']
# words ['body_of_water', 'e1', 'geography', 'island']
# words ['administrative_division', 'administrative_division_capital_relationship', 'capital_of', 'capital_of_administrative_division', 'e1', 'location', 'texas']
# words ['containedby', 'e1', 'located', 'location']
# words ['actor', 'appeared_in_tv_program', 'desperate', 'e1', 'housewives', 'plays', 'regular_tv_appearance', 'tv', 'tv_character']
# words ['did', 'e1', 'education', 'institution', 'people', 'person', 'school']
# words ['e1', 'night', 'tourist_attractions', 'travel', 'travel_destination']
# words ['country', 'e1', 'form_of_government', 'government', 'location', 'today']
# words ['american_football', 'e1', 'football_roster_position', 'pro_athlete', 'sports', 'team', 'teams']
# words ['e1', 'parents', 'people', 'person', 'queen']
# words ['come', 'e1', 'human_language', 'language', 'language_family']
# words ['base', 'celebrity', 'e1', 'husband', 'infidelity', 'infidelity_victim', 'perpetrator', 'popstra']
# words ['base', 'border', 'continent', 'countries', 'does', 'e1', 'locations']
# words ['did', 'e1', 'land', 'nationality', 'people', 'person']
# words ['country', 'e1', 'language', 'location', 'official_language']
# words ['containedby', 'e1', 'located', 'location']
# words ['district', 'district_represented', 'does', 'e1', 'government', 'government_position_held', 'government_positions_held', 'politician', 'represent']
# words ['countries', 'does', 'e1', 'export', 'exported_to', 'imports_and_exports', 'location', 'places_exported_to', 'statistical_region', 'wheat']
# words ['e1', 'military', 'military_combatant', 'military_command', 'military_commander', 'military_commanders', 'queen', 'tribe']
# words ['does', 'e1', 'former_team_s', 'hockey_player', 'hockey_previous_roster_position', 'ice_hockey', 'play', 'team']
# words ['2012', 'does', 'e1', 'football_player', 'football_player_loan', 'lending_team', 'loans', 'play', 'soccer']
# words ['containedby', 'e1', 'located', 'location']
# words ['country', 'dialects', 'e1', 'language', 'location', 'official', 'official_language']
# words ['administrative_division', 'country', 'e1', 'location']
# words ['author', 'biggie', 'book', 'book_editions_published', 'e1', 'killed']
# words ['actor', 'boyfriend', 'e1', 'elaine', 'film', 'film_character', 'performance', 'played', 'portrayed_in_films']
# words ['american_football', 'does', 'e1', 'football_player', 'former_teams', 'play', 'sports', 'sports_team_roster', 'team']
# words ['containedby', 'country', 'e1', 'located', 'location']
# words ['actor', 'avengers', 'e1', 'film', 'film_character', 'movie', 'performance', 'playing', 'portrayed_in_films']
# words ['did', 'drafted', 'drafted_athlete', 'e1', 'nba', 'play', 'sports', 'sports_league_draft_pick', 'team', 'teams']
# words ['artist', 'did', 'e1', 'journey', 'music', 'play', 'role', 'track_contribution', 'track_contributions']
# words ['business', 'company', 'did', 'e1', 'employment_history', 'employment_tenure', 'people', 'person', 'work']
# words ['did', 'e1', 'people', 'person', 'president', 'profession']
# words ['currency', 'dated_money_value', 'e1', 'gdp_real', 'location', 'measurement_unit', 'statistical_region', 'type', 'used']
# words ['e1', 'nationality', 'people', 'person']
# words ['artist', 'does', 'e1', 'live', 'metallica', 'music', 'origin']
# words ['airport', 'e1', 'fly', 'how_to_get_here', 'mode_of_transportation', 'transportation', 'travel', 'travel_destination']
# words ['country', 'does', 'e1', 'exported_to', 'imports_and_exports', 'location', 'places_exported_to', 'statistical_region', 'trade']
# words ['american_football', 'current_team', 'does', 'e1', 'football_player', 'play', 'position', 'sports', 'sports_team_roster']
# words ['belong', 'did', 'e1', 'government', 'party', 'political_party_tenure', 'politician']
# words ['does', 'e1', 'sports', 'sports_team_owner', 'teams', 'teams_owned']
# words ['e1', 'fictional_character', 'fictional_universe', 'place_of_birth', 'princess', 'raised']
# words ['called', 'e1', 'government', 'government_bodies', 'governmental_jurisdiction', 'legislature']
# words ['does', 'e1', 'fantasy_football', 'nfl_team', 'play', 'player', 'szaijan', 'user']
# words ['deceased_person', 'did', 'die', 'e1', 'people', 'place_of_death']
# words ['actor', 'e1', 'film', 'film_character', 'performance', 'played', 'portrayed_in_films']
# words ['e1', 'headquarters', 'located', 'location', 'mailing_address', 'organization', 'state_province_region']
# words ['e1', 'emperor', 'prececessor', 'robert', 'roman_emperor', 'roman_empire', 'user']
# words ['american_football', 'did', 'e1', 'football', 'football_historical_roster_position', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['appointees', 'countries', 'did', 'e1', 'government', 'government_position_held', 'jurisdiction_of_office', 'political_appointer', 'queen', 'rule']
# words ['college', 'did', 'e1', 'education', 'institution', 'people', 'person', 'play']
# words ['american_football', 'coach', 'current_head_coach', 'e1', 'football_team', 'head']
# words ['country', 'e1', 'languages_spoken', 'location', 'speak']
# words ['2010', 'champion', 'default_domain', 'e1', 'hockey_championship', 'played', 'rcheramy', 'teams', 'user']
# words ['basketball', 'basketball_player', 'does', 'e1', 'position', 'sports', 'sports_team_roster', 'team']
# words ['did', 'e1', 'education', 'institution', 'people', 'person', 'school']
# words ['broadcast', 'content', 'e1', 'location', 'studio']
# words ['currency', 'dated_money_value', 'diesel_price_liter', 'e1', 'location', 'measurement_unit', 'statistical_region', 'type', 'used']
# words ['athlete_extra', 'athlete_salary', 'base', 'club', 'does', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['did', 'e1', 'follow', 'people', 'person', 'religion']
# words ['basketball', 'basketball_historical_roster_position', 'drafted', 'e1', 'pro_athlete', 'sports', 'team', 'teams']
# words ['e1', 'film', 'known', 'writer']
# words ['board_member', 'business', 'does', 'e1', 'leader_of', 'leadership', 'organization']
# words ['art', 'associated_periods_or_movements', 'did', 'e1', 'style', 'visual_art', 'visual_artist']
# words ['did', 'e1', 'football_goal', 'football_player', 'goals_scored', 'play', 'point_awarded_to', 'soccer']
# words ['containedby', 'e1', 'located', 'location']
# words ['diary', 'did', 'e1', 'media_common', 'quotation_subject', 'quotations_about_this_subject', 'wrote']
# words ['does', 'e1', 'play', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['does', 'e1', 'location', 'people', 'person', 'place_lived', 'places_lived', 'state']
# words ['e1', 'film', 'movies', 'producer']
# words ['did', 'director', 'e1', 'film', 'movie', 'write']
# words ['american_football', 'does', 'e1', 'football_historical_roster_position', 'play', 'position', 'position_s', 'pro_athlete', 'sports', 'teams']
# words ['aareas', 'administrative_area', 'base', 'calabria', 'e1', 'schema', 'subdividing_type']
# words ['does', 'drafted', 'drafted_athlete', 'e1', 'play', 'sports', 'sports_league_draft_pick', 'team']
# words ['american_football', 'does', 'e1', 'football_roster_position', 'play', 'position', 'pro_athlete', 'sports', 'teams']
# words ['artist', 'does', 'e1', 'live', 'metallica', 'music', 'origin']
# words ['country', 'currency', 'currency_used', 'e1', 'location']
# words ['deities', 'e1', 'gods', 'religion']
# words ['actor', 'did', 'e1', 'film', 'movies', 'performance', 'play']
# words ['base', 'ben', 'contained_by', 'does', 'e1', 'live', 'location_in_fiction', 'militaryinfiction', 'stiller']
# words ['2011', 'athlete_extra', 'athlete_salary', 'base', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['county', 'e1', 'hud_county_place', 'il', 'location']
# words ['citytown', 'e1', 'headquarters', 'location', 'mailing_address', 'organization']
# words ['e1', 'places', 'tourist_attractions', 'travel', 'travel_destination']
# words ['e1', 'film', 'film_character', 'names', 'performance', 'portrayed_in_films', 'potter']
# words ['assassin', 'assassinated_person', 'assassination', 'default_domain', 'dfhuynh', 'e1', 'killed', 'shot', 'user']
# words ['basketball', 'basketball_roster_position', 'did', 'e1', 'play', 'position', 'pro_athlete', 'sports', 'teams']
# words ['cvg', 'e1', 'game_character', 'game_performance', 'games', 'voice', 'voice_actor']
# words ['base', 'continent', 'countries', 'e1', 'located', 'locations']
# words ['children', 'e1', 'people', 'person', 'son']
# words ['county', 'e1', 'hud_county_place', 'location']
# words ['capital', 'e1', 'location', 'state', 'us_state']
# words ['country', 'did', 'e1', 'famous', 'olympic_athlete', 'olympic_athlete_affiliation', 'olympics']
# words ['accommodation', 'e1', 'stay', 'travel', 'travel_destination']
# words ['base', 'base_equivalent_location', 'default_domain', 'e1', 'map', 'narphorium', 'user']
# words ['04', 'city', 'citytown', 'e1', 'fc', 'headquarters', 'location', 'mailing_address', 'organization']
# words ['2011', 'appointed_by', 'e1', 'governing_officials', 'government', 'government_position_held', 'governmental_jurisdiction', 'governor', 'new']
# words ['does', 'e1', 'play', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['administrative_division', 'administrative_division_capital_relationship', 'capital', 'e1', 'location']
# words ['e1', 'people', 'person', 'profession']
# words ['bio', 'e1', 'marriage', 'people', 'person', 'spouse', 'spouse_s', 'wife']
# words ['aareas', 'administrative_area', 'administrative_parent', 'base', 'e1', 'map', 'miguel', 'san', 'schema']
# words ['american_football', 'does', 'e1', 'football_player', 'play', 'player_rushing_statistics', 'rushing', 'team']
# words ['doing', 'e1', 'people', 'person', 'profession']
# words ['cvg', 'cvg_developer', 'did', 'e1', 'game_versions_developed', 'games', 'make']
# words ['city', 'did', 'e1', 'live', 'people', 'person', 'place_of_birth']
# words ['containedby', 'did', 'e1', 'live', 'location']
# words ['country', 'currency_used', 'e1', 'location', 'money', 'used']
# words ['born', 'e1', 'people', 'person', 'place_of_birth']
# words ['did', 'e1', 'name_source', 'namesakes', 'symbols']
# words ['basketball', 'basketball_roster_position', 'basketball_team', 'current', 'e1', 'player', 'roster']
# words ['damaged_by_disasters', 'disaster_affected_structure', 'e1', 'event', 'happened', 'nuclear', 'plant']
# words ['distilled_spirits', 'distillery', 'e1', 'region', 'tennessee', 'whiskey']
# words ['did', 'dylanrocks', 'e1', 'national_football_league', 'nfl_teams_that_have_moved_cities', 'old_team_name', 'originate', 'user']
# words ['citytown', 'e1', 'headquarters', 'located', 'location', 'mailing_address', 'organization']
# words ['e1', 'sights', 'tourist_attractions', 'travel', 'travel_destination']
# words ['deceased_person', 'did', 'e1', 'grow', 'people', 'place_of_death']
# words ['containedby', 'county', 'e1', 'location']
# words ['does', 'e1', 'money', 'people', 'person', 'profession']
# words ['actor', 'appeared_in_tv_program', 'e1', 'fringe', 'plays', 'regular_tv_appearance', 'tv', 'tv_character']
# words ['capital', 'country', 'e1', 'location', 'map']
# words ['created', 'e1', 'founders', 'organization']
# words ['e1', 'location', 'time', 'time_zones']
# words ['american_football', 'does', 'e1', 'football_roster_position', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['base', 'did', 'disability', 'disabled_person', 'disease', 'e1', 'qualia', 'type_of_disability']
# words ['county', 'e1', 'transport_terminus', 'transportation', 'travel', 'travel_destination', 'travel_destinations_served']
# words ['border', 'contains', 'does', 'e1', 'location']
# words ['actor', 'appeared_in_tv_program', 'e1', 'family', 'guy', 'plays', 'regular_tv_appearance', 'tv', 'tv_character']
# words ['2011', 'american_football', 'does', 'e1', 'football_historical_roster_position', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['actor', 'e1', 'griffin', 'plays', 'regular_cast', 'regular_tv_appearance', 'stewie', 'tv', 'tv_program', 'voice']
# words ['did', 'e1', 'play', 'sports', 'sports_team_coach', 'sports_team_coach_tenure', 'team', 'teams_coached']
# words ['actor', 'e1', 'film', 'movies', 'performance']
# words ['2010', 'does', 'e1', 'live', 'location', 'people', 'person', 'place_lived', 'places_lived', 'right']
# words ['basketball', 'basketball_player', 'basketball_roster_position', 'did', 'e1', 'sign', 'team']
# words ['2010', 'basketball', 'basketball_player', 'does', 'e1', 'play', 'position_s']
# words ['actor', 'does', 'e1', 'family', 'film', 'film_character', 'guy', 'performance', 'portrayed_in_films', 'voice']
# words ['dataworld', 'e1', 'gardening_hint', 'missouri', 'split_to']
# words ['attend', 'college', 'did', 'e1', 'education', 'institution', 'people', 'person']
# words ['country', 'does', 'e1', 'export', 'imported_from', 'imports_and_exports', 'location', 'places_imported_from', 'statistical_region']
# words ['come', 'country', 'does', 'e1', 'human_language', 'language', 'main_country']
# words ['country', 'e1', 'economy', 'form_of_government', 'kind', 'location']
# words ['base', 'baseball', 'e1', 'facility', 'play', 'schemastaging', 'sports_team_extra', 'team_training_ground_relationship', 'training_ground']
# words ['county', 'e1', 'hud_county_place', 'location']
# words ['containedby', 'e1', 'glastonbury', 'location']
# words ['come', 'country', 'did', 'e1', 'nationality', 'people', 'person', 'vasco']
# words ['did', 'e1', 'education', 'institution', 'people', 'person', 'school']
# words ['award', 'award_honor', 'award_winner', 'award_winning_work', 'awards_won', 'black', 'e1', 'jacob', 'plays']
# words ['country', 'does', 'e1', 'economy', 'form_of_government', 'kind', 'location']
# words ['basketball', 'basketball_roster_position', 'does', 'e1', 'nba', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['basketball', 'basketball_historical_roster_position', 'basketball_player', 'e1', 'former_teams', 'team']
# words ['argumentmaps', 'base', 'did', 'discover', 'e1', 'innovator', 'invent', 'original_ideas']
# words ['baby', 'did', 'e1', 'marriage', 'people', 'person', 'spouse', 'spouse_s']
# words ['aareas', 'administrative_area', 'administrative_children', 'base', 'e1', 'places', 'schema', 'visit']
# words ['basketball', 'basketball_player', 'basketball_roster_position', 'did', 'e1', 'play', 'team']
# words ['e1', 'location', 'right', 'time', 'time_zones', 'zone']
# words ['american_football', 'does', 'e1', 'football_player', 'games', 'play', 'player_game_statistics', 'team']
# words ['basketball', 'basketball_roster_position', 'does', 'e1', 'nba', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['basketball', 'basketball_roster_position', 'e1', 'lineup', 'player', 'roster', 'sports', 'sports_team', 'starting']
# words ['associated_periods_or_movements', 'did', 'e1', 'paintings', 'type', 'visual_art', 'visual_artist']
# words ['athlete_extra', 'athlete_salary', 'base', 'did', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['country', 'e1', 'languages_spoken', 'location', 'speak']
# words ['accomplish', 'did', 'e1', 'name_source', 'namesakes', 'symbols']
# words ['adjoin_s', 'adjoining_relationship', 'adjoins', 'border', 'countries', 'does', 'e1', 'location']
# words ['country', 'e1', 'nationality', 'people', 'person', 'sail', 'vasco']
# words ['e1', 'played', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['e1', 'fictional_character', 'fictional_universe', 'life', 'marriage_of_fictional_characters', 'married', 'married_to', 'real', 'spouses']
# words ['airport', 'close', 'e1', 'location', 'nearby_airports']
# words ['american_football', 'did', 'e1', 'football_player', 'leave', 'player_rushing_statistics', 'rushing', 'season', 'usc']
# words ['actor', 'appeared_in_tv_program', 'e1', 'plays', 'regular_tv_appearance', 'tv', 'tv_character', 'wire']
# words ['e1', 'government', 'government_position_held', 'government_positions_held', 'governor', 'jurisdiction_of_office', 'politician', 'state']
# words ['basketball', 'basketball_player', 'basketball_player_stats', 'did', 'e1', 'player_statistics', 'rings', 'team', 'teams', 'won']
# words ['does', 'e1', 'end', 'geography', 'mouth', 'river']
# words ['aareas', 'administrative_area', 'base', 'capital', 'city', 'e1', 'schema', 'usa']
# words ['e1', 'elected', 'location', 'people', 'person', 'place_lived', 'places_lived', 'state']
# words ['ben', 'containedby', 'does', 'e1', 'live', 'location', 'stiller']
# words ['currency', 'dated_money_value', 'e1', 'gdp_real', 'location', 'measurement_unit', 'statistical_region']
# words ['basketball', 'basketball_team', 'e1', 'lineup', 'player', 'roster', 'sports', 'sports_team_roster', 'starting']
# words ['2013', 'does', 'e1', 'play', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['deceased_person', 'did', 'die', 'e1', 'people', 'place_of_death']
# words ['e1', 'government', 'government_position_held', 'jurisdiction_of_office', 'political_district', 'representatives', 'spain']
# words ['american_football', 'current_team', 'does', 'e1', 'football_player', 'football_roster_position', 'play', 'team']
# words ['e1', 'known', 'people', 'person', 'profession']
# words ['2012', 'country', 'currency', 'currency_used', 'e1', 'location', 'used']
# words ['country', 'e1', 'language', 'location', 'mainly', 'official_language', 'spoken']
# words ['city', 'containedby', 'e1', 'location']
# words ['did', 'e1', 'fight', 'military', 'military_force', 'military_person', 'military_service', 'service']
# words ['cause_of_death', 'deceased_person', 'did', 'died', 'e1', 'people']
# words ['containedby', 'e1', 'located', 'location', 'state']
# words ['blowers', 'e1', 'organization', 'place_founded', 'snow']
# words ['did', 'e1', 'gold', 'medal', 'medals_won', 'olympic_athlete', 'olympic_medal_honor', 'olympics', 'won']
# words ['business', 'e1', 'employees', 'employer', 'employment_tenure', 'person', 'started']
# words ['e1', 'location', 'stay', 'thailand', 'time_zones']
# words ['e1', 'founders', 'organization', 'started']
# words ['country', 'currency_used', 'does', 'e1', 'kind', 'location', 'money', 'use']
# words ['administrative_division', 'administrative_division_capital_relationship', 'capital_of', 'capital_of_administrative_division', 'county', 'e1', 'location']
# words ['contribute', 'did', 'e1', 'name_source', 'namesakes', 'science', 'symbols']
# words ['base', 'clinton', 'e1', 'elected', 'nominated_at', 'politicalconventions', 'presidential_nominee']
# words ['e1', 'names', 'parents', 'people', 'person']
# words ['did', 'e1', 'live', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['condition', 'did', 'e1', 'illnesses', 'medicine', 'notable_person_with_medical_condition', 'suffer']
# words ['artist', 'did', 'e1', 'moon', 'music', 'say', 'track']
# words ['college', 'did', 'e1', 'education', 'institution', 'people', 'person']
# words ['did', 'e1', 'living', 'people', 'person', 'profession']
# words ['adjectival_form', 'e1', 'location', 'people', 'speak']
# words ['did', 'e1', 'live', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['coach', 'e1', 'head', 'hockey_team', 'ice_hockey']
# words ['did', 'e1', 'education', 'graduate', 'institution', 'people', 'person', 'university']
# words ['containedby', 'country', 'e1', 'located', 'location', 'modern']
# words ['e1', 'england', 'location', 'time', 'time_zones', 'zone']
# words ['did', 'e1', 'former_team_s', 'hockey_player', 'ice_hockey', 'play', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['basketball', 'basketball_player', 'basketball_roster_position', 'does', 'e1', 'position', 'team']
# words ['did', 'district_represented', 'e1', 'government', 'government_position_held', 'government_positions_held', 'live', 'politician', 'state']
# words ['2010', 'american_football', 'does', 'e1', 'football_historical_roster_position', 'football_player', 'former_teams', 'nov', 'play', 'team']
# words ['come', 'country', 'does', 'e1', 'language', 'location', 'official_language']
# words ['containedby', 'e1', 'location', 'map']
# words ['county', 'e1', 'hud_county_place', 'located', 'location']
# words ['containedby', 'e1', 'located', 'location']
# words ['come', 'dataworld', 'did', 'e1', 'gardening_hint', 'people', 'split_to']
# words ['children', 'daughter', 'e1', 'people', 'person']
# words ['actor', 'e1', 'film', 'film_character', 'friend', 'performance', 'played', 'portrayed_in_films', 'terminator']
# words ['artist', 'e1', 'influence', 'influence_node', 'influenced', 'influenced_by']
# words ['college', 'e1', 'education', 'institution', 'people', 'person']
# words ['coach', 'coaches', 'e1', 'head', 'sports', 'sports_team', 'sports_team_coach_tenure']
# words ['country', 'does', 'e1', 'form_of_government', 'government', 'kind', 'location', 'today']
# words ['2012', 'country', 'currency', 'dated_money_value', 'e1', 'gdp_nominal_per_capita', 'location', 'measurement_unit', 'used']
# words ['county_seat', 'did', 'e1', 'location', 'place', 'tale', 'us_county']
# words ['does', 'e1', 'play', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['basketball', 'basketball_player', 'basketball_roster_position', 'did', 'e1', 'play', 'team']
# words ['american', 'e1', 'ethnicity', 'language', 'languages_spoken', 'native', 'people', 'speak']
# words ['country', 'currency', 'currency_used', 'does', 'e1', 'kind', 'location']
# words ['did', 'drafted', 'drafted_athlete', 'e1', 'school', 'sports', 'sports_league_draft_pick', 'traded']
# words ['e1', 'marriage', 'people', 'person', 'spouse', 'spouse_s', 'wife']
# words ['actor', 'e1', 'film', 'film_character', 'hobbit', 'movie', 'performance', 'playing', 'portrayed_in_films']
# words ['country', 'did', 'e1', 'explored', 'nationality', 'people', 'person']
# words ['born', 'country', 'e1', 'nationality', 'people', 'person']
# words ['2010', 'does', 'e1', 'live', 'people', 'person', 'place_of_birth']
# words ['country', 'currency', 'currency_used', 'does', 'e1', 'location', 'use']
# words ['american', 'e1', 'military', 'military_force', 'military_person', 'military_service', 'revolution', 'service']
# words ['baby', 'base', 'canoodled', 'celebrity', 'did', 'e1', 'participant', 'popstra']
# words ['auburn', 'did', 'e1', 'education', 'institution', 'people', 'person', 'school']
# words ['containedby', 'e1', 'location', 'map', 'world']
# words ['basketball', 'basketball_roster_position', 'did', 'e1', 'nba', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['band', 'e1', 'group_membership', 'member', 'music', 'musical_group']
# words ['adjoin_s', 'adjoining_relationship', 'adjoins', 'border', 'countries', 'e1', 'location']
# words ['country', 'dialects', 'e1', 'location', 'official_language']
# words ['baseball', 'baseball_player', 'did', 'e1', 'former_teams', 'play', 'sports', 'sports_team_roster', 'team']
# words ['did', 'e1', 'founded', 'sports', 'sports_team', 'start', 'year']
# words ['adjoin_s', 'adjoining_relationship', 'adjoins', 'e1', 'located', 'location', 'spain']
# words ['country', 'does', 'e1', 'language', 'location', 'official_language', 'people', 'speak']
# words ['administrative_division', 'e1', 'first_level_division_of', 'located', 'location']
# words ['change', 'e1', 'location', 'time', 'time_zones']
# words ['business', 'created', 'e1', 'employees', 'employer', 'employment_tenure', 'person']
# words ['e1', 'living', 'people', 'person', 'profession']
# words ['aareas', 'administrative_area', 'base', 'bluegrass', 'capital', 'e1', 'known', 'schema']
# words ['colony', 'e1', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['countries', 'e1', 'location', 'partially_contains']
# words ['american_football', 'does', 'e1', 'football_historical_roster_position', 'football_player', 'former_teams', 'play', 'team']
# words ['2011', 'american_football', 'e1', 'football_historical_roster_position', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['e1', 'human_language', 'language', 'language_family', 'origin']
# words ['e1', 'location', 'time_zones', 'timezone']
# words ['e1', 'people', 'person', 'place_of_birth', 'raised']
# words ['country', 'e1', 'language', 'location', 'official_language', 'speak']
# words ['country', 'e1', 'language', 'languages_spoken', 'location', 'major']
# words ['countries', 'e1', 'member', 'members', 'membership_organization', 'organization', 'organization_membership']
# words ['does', 'e1', 'live', 'people', 'person', 'place_of_birth']
# words ['base', 'district_represented', 'e1', 'elected_government_positions_held', 'elected_official', 'elected_positions_held', 'government2', 'senator', 'state']
# words ['country', 'e1', 'language', 'location', 'official', 'official_language', 'spoken']
# words ['e1', 'marriage', 'married', 'people', 'person', 'spouse', 'spouse_s']
# words ['appeared_in_tv_program', 'does', 'e1', 'mean', 'regular_tv_appearance', 'series', 'tv', 'tv_character']
# words ['did', 'e1', 'empire', 'kingdom', 'monarch', 'royalty', 'rule']
# words ['country', 'e1', 'ghana', 'language', 'location', 'official_language', 'speak']
# words ['club', 'e1', 'football_goal', 'football_player', 'goals_scored', 'point_awarded_to', 'soccer', 'team']
# words ['drafted', 'drafted_athlete', 'e1', 'sports', 'sports_league_draft_pick', 'team']
# words ['e1', 'government', 'groups', 'involved', 'party', 'political_party_tenure', 'politician']
# words ['e1', 'influence', 'influence_node', 'influenced', 'influenced_by', 'work']
# words ['country', 'currency', 'currency_formerly_used', 'e1', 'location']
# words ['does', 'e1', 'ethnicity', 'language', 'languages_spoken', 'people', 'use']
# words ['e1', 'named_after', 'namesake', 'parents', 'symbols']
# words ['e1', 'medium', 'named_after', 'namesake', 'school', 'symbols']
# words ['base', 'biblioness', 'bibs_location', 'country', 'e1', 'golf', 'masters']
# words ['2013', 'athlete_extra', 'athlete_salary', 'base', 'does', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['base', 'e1', 'equivalent_concept', 'located', 'skosbase', 'spain', 'vocabulary_equivalent_topic']
# words ['did', 'e1', 'play', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['accommodation', 'best', 'e1', 'hotels', 'stay', 'travel', 'travel_destination']
# words ['actor', 'appeared_in_tv_program', 'e1', 'general', 'hospital', 'played', 'regular_tv_appearance', 'tv', 'tv_character']
# words ['belong', 'did', 'e1', 'government', 'party', 'political', 'political_party_tenure', 'politician']
# words ['aareas', 'adjectival_form', 'administrative_area', 'base', 'considered', 'e1', 'people', 'schema']
# words ['actor', 'e1', 'film', 'film_character', 'performance', 'plays', 'portrayed_in_films']
# words ['did', 'e1', 'live', 'nationality', 'people', 'person']
# words ['basketball', 'basketball_roster_position', 'e1', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['associated_periods_or_movements', 'did', 'e1', 'paintings', 'technique', 'use', 'visual_art', 'visual_artist']
# words ['e1', 'headquarters', 'located', 'location', 'mailing_address', 'organization', 'state_province_region']
# words ['containedby', 'e1', 'located', 'location']
# words ['e1', 'island', 'people', 'person', 'place_of_birth']
# words ['border', 'countries', 'does', 'e1', 'exported_to', 'imports_and_exports', 'location', 'places_exported_to', 'statistical_region']
# words ['basketball', 'basketball_player', 'does', 'e1', 'nba', 'play', 'sports', 'sports_team_roster', 'team']
# words ['countries_spoken_in', 'e1', 'human_language', 'language', 'located']
# words ['did', 'e1', 'program_creator', 'tv', 'tv_program', 'voice']
# words ['base', 'did', 'discover', 'e1', 'nobel_honor', 'nobel_prize_winner', 'nobelprizes', 'particles', 'subatomic', 'subject_area']
# words ['baron', 'cause_of_death', 'deceased_person', 'did', 'die', 'e1', 'people']
# words ['called', 'e1', 'government', 'governmental_body', 'judge', 'offices_positions']
# words ['2012', 'basketball', 'basketball_player', 'does', 'e1', 'former_teams', 'play', 'sports', 'sports_team_roster', 'team']
# words ['actor', 'does', 'e1', 'film', 'movies', 'performance', 'star']
# words ['capital', 'city', 'containedby', 'e1', 'location']
# words ['did', 'e1', 'nba', 'play', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['deceased_person', 'e1', 'home', 'people', 'place_of_burial']
# words ['country', 'e1', 'location', 'official_language', 'people', 'speak']
# words ['countries', 'e1', 'location', 'partially_containedby', 'region']
# words ['base', 'did', 'e1', 'imprisoned', 'imprisonment', 'jail', 'prison', 'prisoner']
# words ['did', 'e1', 'gender', 'like', 'look', 'people', 'person']
# words ['common', 'e1', 'practices', 'religion', 'religions']
# words ['born', 'city', 'e1', 'people', 'person', 'place_of_birth']
# words ['basketball', 'basketball_historical_roster_position', 'basketball_player', 'does', 'e1', 'former_teams', 'play', 'team']
# words ['country', 'currency', 'currency_used', 'e1', 'location']
# words ['citytown', 'code', 'e1', 'location', 'postal_codes', 'zip']
# words ['college', 'did', 'e1', 'education', 'institution', 'people', 'person']
# words ['e1', 'gmt', 'location', 'time_zones', 'timezone']
# words ['american_football', 'did', 'e1', 'football_historical_roster_position', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['art_subject', 'artwork_on_the_subject', 'died', 'e1', 'visual_art']
# words ['e1', 'marriage', 'married', 'people', 'person', 'spouse', 'spouse_s']
# words ['basketball', 'basketball_historical_roster_position', 'basketball_player', 'did', 'e1', 'former_teams', 'play', 'team', 'teams']
# words ['draft', 'drafted', 'drafted_athlete', 'e1', 'got', 'sports', 'sports_league_draft_pick']
# words ['affected_areas', 'did', 'e1', 'meteorology', 'tropical_cyclone']
# words ['country', 'e1', 'location', 'official_language', 'people', 'speak']
# words ['award', 'award_nomination', 'award_nominations', 'award_nominee', 'does', 'e1', 'movies', 'nominated_for', 'play']
# words ['american', 'biology', 'e1', 'higher_classification', 'organism_classification', 'terriers']
# words ['containedby', 'e1', 'hong', 'kong', 'location']
# words ['appliances', 'base', 'e1', 'organization_extra', 'phone_number', 'phone_sandbox', 'schemastaging', 'service_location']
# words ['called', 'e1', 'flag', 'flag_referent', 'flag_use', 'state', 'symbols']
# words ['did', 'e1', 'live', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['does', 'e1', 'play', 'position', 'pro_athlete', 'sports', 'sports_team_roster', 'teams']
# words ['e1', 'fictional_character', 'fictional_universe', 'mother', 'parents', 'played', 'star', 'wars']
# words ['colosseum', 'e1', 'film', 'film_subject', 'films', 'used']
# words ['athlete_extra', 'athlete_salary', 'base', 'currently', 'does', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['administrative_division', 'administrative_division_capital_relationship', 'capital_of', 'capital_of_administrative_division', 'county', 'e1', 'location']
# words ['current_frequency', 'e1', 'recurring_event', 'tennis', 'time', 'tournament']
# words ['e1', 'medium', 'name_source', 'namesakes', 'school', 'symbols']
# words ['american_football', 'current_team', 'does', 'e1', 'football_player', 'play', 'sports', 'sports_team_roster', 'team']
# words ['e1', 'people', 'person', 'profession']
# words ['affected_area', 'affected_locations', 'did', 'e1', 'earthquake', 'earthquake_effect', 'earthquakes', 'occur', 'robert', 'user']
# words ['e1', 'known', 'people', 'person', 'profession']
# words ['baseball', 'did', 'e1', 'founded', 'playing', 'sports', 'sports_team', 'start']
# words ['e1', 'job', 'people', 'person', 'profession']
# words ['2012', 'american_football', 'did', 'e1', 'football_historical_roster_position', 'pro_athlete', 'sign', 'sports', 'team', 'teams']
# words ['country', 'e1', 'kind', 'language', 'location', 'official_language', 'speak']
# words ['american_football', 'does', 'e1', 'football_player', 'former_teams', 'play', 'sports', 'sports_team_roster', 'team']
# words ['adjectival_form', 'considered', 'e1', 'location', 'people']
# words ['e1', 'government', 'government_position_held', 'government_positions_held', 'life', 'office_position_or_title', 'politician', 'real']
# words ['award', 'award_nomination', 'award_nominations', 'award_nominee', 'does', 'e1', 'movie', 'nominated_for', 'play']
# words ['did', 'e1', 'living', 'people', 'person', 'profession']
# words ['american_football', 'does', 'e1', 'football_historical_roster_position', 'football_player', 'former_teams', 'play', 'team']
# words ['born', 'e1', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['born', 'country', 'e1', 'people', 'person', 'place_of_birth']
# words ['2011', 'american_football', 'coach', 'e1', 'football_historical_coach_position', 'football_team', 'historical_coaching_staff']
# words ['alexander', 'e1', 'misc', 'murdered_by', 'murdered_person', 'shot', 'user']
# words ['e1', 'marriage', 'married', 'people', 'person', 'spouse', 'spouse_s']
# words ['base', 'biblioness', 'bibs_location', 'country', 'e1']
# words ['basketball', 'basketball_player', 'did', 'e1', 'former_teams', 'play', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['consist', 'contains', 'does', 'e1', 'location']
# words ['base', 'e1', 'famouspets', 'owner', 'pet_owner', 'pet_ownership', 'pets_owned', 'wife']
# words ['artwork', 'e1', 'influence', 'influence_node', 'influenced', 'influenced_by']
# words ['did', 'e1', 'education', 'institution', 'people', 'person', 'school', 'went']
# words ['born', 'e1', 'people', 'person', 'place_of_birth']
# words ['deceased_person', 'e1', 'people', 'place_of_death']
# words ['2010', 'aareas', 'administrative_area', 'administrative_parent', 'base', 'e1', 'schema', 'spain']
# words ['alcohol', 'dataworld', 'e1', 'gardening_hint', 'kind', 'split_to']
# words ['artist', 'e1', 'music', 'origin']
# words ['citytown', 'e1', 'korea', 'location', 'postal_codes', 'postcode', 'south']
# words ['capital', 'city', 'country', 'e1', 'location']
# words ['different', 'e1', 'sports', 'sports_team_location', 'teams']
# words ['country', 'does', 'e1', 'form_of_government', 'government', 'kind', 'location']
# words ['county', 'e1', 'geography', 'located', 'mouth', 'river']
# words ['africa', 'base', 'e1', 'equivalent_concept', 'skosbase', 'south', 'vocabulary_equivalent_topic']
# words ['business', 'company', 'e1', 'employment_history', 'employment_tenure', 'people', 'person', 'school']
# words ['country', 'e1', 'location', 'partially_containedby']
# words ['called', 'country', 'currency_formerly_used', 'dollars', 'e1', 'location']
# words ['does', 'e1', 'human_language', 'language', 'language_family', 'like', 'sound']
# words ['boyfriend', 'character_created_by', 'e1', 'elaine', 'fictional_character', 'fictional_universe', 'played']
# words ['did', 'died', 'e1', 'location', 'people', 'person', 'place', 'place_lived', 'places_lived']
# words ['e1', 'headquarters', 'location', 'mailing_address', 'microwaves', 'organization', 'state_province_region']
# words ['containedby', 'e1', 'florida', 'location']
# words ['country', 'does', 'e1', 'location', 'official_language', 'speak']
# words ['college', 'did', 'e1', 'founder', 'organization', 'place_founded']
# words ['board_members', 'e1', 'member', 'organization', 'organization_board_membership', 'started']
# words ['e1', 'influence', 'influence_node', 'influenced_by', 'sculpt', 'taught']
# words ['come', 'did', 'e1', 'nationality', 'people', 'person']
# words ['current_team', 'does', 'e1', 'football_player', 'play', 'soccer', 'sports', 'sports_team_roster', 'team']
# words ['containedby', 'e1', 'location', 'situated']
# words ['destination_city', 'did', 'dylanrocks', 'e1', 'hit', 'national_football_league', 'nfl_teams_that_have_moved_cities', 'tornado', 'user']
# words ['2011', 'american_football', 'does', 'e1', 'football_player', 'games', 'play', 'player_game_statistics', 'season', 'team']
# words ['award', 'award_honor', 'award_winner', 'awards_won', 'book', 'bowl', 'did', 'dust', 'e1', 'honored_for', 'people', 'wrote']
# words ['accomplice', 'argumentmaps', 'base', 'decision_maker', 'decision_making_person_or_group', 'e1', 'motivation']
# words ['e1', 'headquarters', 'location', 'mailing_address', 'organization', 'state_province_region', 'wellsville']
# words ['american_football', 'does', 'e1', 'football_historical_roster_position', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['country', 'currency_used', 'e1', 'location', 'money', 'use']
# words ['currency', 'dated_money_value', 'e1', 'external_debt_stock', 'location', 'measurement_unit', 'statistical_region']
# words ['chapel', 'deceased_person', 'e1', 'people', 'place_of_death', 'sistine']
# words ['begin', 'does', 'e1', 'geography', 'origin', 'river']
# words ['awards', 'celtics', 'did', 'e1', 'play', 'sports', 'sports_award', 'sports_award_winner', 'team']
# words ['e1', 'regular_tv_appearance', 'series', 'starring_roles', 'tv', 'tv_actor']
# words ['drafted', 'drafted_athlete', 'e1', 'sports', 'sports_league_draft_pick', 'team']
# words ['e1', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['athlete_extra', 'athlete_salary', 'base', 'does', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['administrative_division', 'come', 'country', 'did', 'e1', 'location', 'terriers']
# words ['author', 'book', 'cells', 'contribute', 'did', 'e1', 'understanding', 'works_written']
# words ['actor', 'does', 'e1', 'film', 'movies', 'performance', 'play']
# words ['basketball', 'basketball_roster_position', 'did', 'e1', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['cause', 'cause_of_death', 'death', 'deceased_person', 'e1', 'people']
# words ['baseball', 'did', 'e1', 'play', 'pro_athlete', 'professional', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['e1', 'influence', 'influence_node', 'influenced', 'influenced_by', 'work']
# words ['base', 'continent', 'countries', 'e1', 'hong', 'kong', 'locations']
# words ['containedby', 'e1', 'location']
# words ['citytown', 'e1', 'headquarters', 'location', 'mailing_address', 'nations', 'organization', 'united']
# words ['did', 'e1', 'live', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['country', 'e1', 'languages', 'location', 'main', 'official_language', 'spoken']
# words ['containedby', 'e1', 'location', 'uk']
# words ['basketball', 'basketball_player', 'basketball_roster_position', 'drafted', 'e1', 'team', 'teams']
# words ['does', 'e1', 'live', 'nationality', 'people', 'person']
# ...
# words ['airport', 'does', 'e1', 'fly', 'location', 'nearby_airports', 'southwest']
# words ['did', 'e1', 'influence', 'influence_node', 'influenced', 'inspired']
# words ['basketball', 'basketball_player', 'did', 'e1', 'play', 'position', 'position_s']
# words ['country', 'e1', 'language', 'location', 'mainly', 'official_language', 'spoken']
# words ['adjoin_s', 'adjoining_relationship', 'adjoins', 'borders', 'countries', 'e1', 'location', 'share']
# words ['base', 'car', 'does', 'e1', 'make', 'models', 'organization_extra', 'phone_number', 'phone_sandbox', 'product_or_service', 'schemastaging']
# words ['artist', 'did', 'e1', 'live', 'music', 'origin']
# words ['actor', 'e1', 'film', 'film_character', 'performance', 'portrayed_in_films', 'real']
# words ['e1', 'location', 'time_zones', 'timezone']
# words ['championships', 'e1', 'series', 'sports', 'sports_team', 'world', 'year']
# words ['artist', 'compose', 'did', 'e1', 'genre', 'music']
# words ['did', 'e1', 'education', 'institution', 'people', 'person', 'school', 'went']
# words ['2012', 'e1', 'leader', 'military', 'military_combatant', 'military_command', 'military_commander', 'military_commanders']
# words ['artist', 'e1', 'label', 'lyrics', 'meaning', 'music', 'want']
# words ['casualties', 'e1', 'happening', 'military', 'military_combatant', 'military_conflict', 'right']
# words ['athlete_extra', 'athlete_salary', 'base', 'does', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['bring', 'country', 'currency_used', 'e1', 'location', 'money']
# words ['e1', 'headquarters', 'location', 'mailing_address', 'organization', 'state_province_region']
# words ['actor', 'e1', 'film', 'film_character', 'performance', 'plays', 'portrayed_in_films']
# words ['country', 'does', 'e1', 'form_of_government', 'government', 'location', 'type']
# words ['e1', 'founders', 'invented', 'organization']
# words ['currency', 'dated_money_value', 'e1', 'location', 'measurement_unit', 'rent50_1', 'statistical_region', 'type', 'used']
# words ['base', 'currency', 'dated_money_value', 'e1', 'governments_that_debase', 'largest_denomination', 'measurement_unit', 'monetarydebase']
# words ['does', 'e1', 'fall', 'family', 'human_language', 'language', 'language_family']
# words ['country', 'e1', 'language', 'languages_spoken', 'location', 'speak']
# words ['athlete_extra', 'athlete_salary', 'base', 'did', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['american_football', 'does', 'e1', 'football_historical_roster_position', 'football_player', 'former_teams', 'play', 'position', 'position_s']
# words ['did', 'e1', 'grew', 'people', 'person', 'place_of_birth']
# words ['base', 'continent', 'countries', 'e1', 'locations']
# words ['deceased_person', 'e1', 'known', 'people', 'place_of_death']
# words ['e1', 'marriage', 'people', 'person', 'spouse', 'spouse_s', 'wife']
# words ['e1', 'famous', 'people', 'person', 'profession']
# words ['did', 'dylanrocks', 'e1', 'national_football_league', 'nfl_teams_that_have_moved_cities', 'original_city', 'user']
# words ['containedby', 'did', 'e1', 'live', 'location']
# words ['e1', 'people', 'person', 'profession']
# words ['did', 'e1', 'marriage', 'marry', 'people', 'person', 'spouse', 'spouse_s']
# words ['basketball', 'basketball_player', 'did', 'e1', 'play', 'position_s']
# words ['e1', 'ethnicity', 'people', 'queen', 'tribe']
# words ['2010', 'does', 'e1', 'nov', 'play', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['containedby', 'e1', 'location', 'map', 'miguel', 'san']
# words ['e1', 'imported_from', 'imports_and_exports', 'location', 'major', 'partners', 'places_imported_from', 'statistical_region', 'trade']
# words ['country', 'e1', 'languages', 'languages_spoken', 'location', 'people', 'speak']
# words ['e1', 'ethnicity', 'ghana', 'language', 'languages_spoken', 'people', 'speak']
# words ['e1', 'famous', 'ga', 'olympic_host_city', 'olympics', 'olympics_hosted']
# words ['country', 'e1', 'government', 'government_bodies', 'governmental_jurisdiction', 'located']
# words ['e1', 'people', 'person', 'profession']
# words ['e1', 'ex', 'marriage', 'people', 'person', 'spouse', 'spouse_s', 'wife']
# words ['e1', 'location', 'texas', 'time_zones', 'timezone']
# words ['does', 'e1', 'people', 'person', 'profession']
# words ['country', 'e1', 'language', 'location', 'official_language', 'primary']
# words ['basketball', 'basketball_roster_position', 'did', 'e1', 'pro_athlete', 'sign', 'sports', 'team', 'teams']
# words ['born', 'country_of_origin', 'e1', 'kids', 'tv', 'tv_program']
# words ['award', 'competitions', 'competitor', 'did', 'e1', 'factor', 'won']
# words ['actor', 'appeared_in_tv_program', 'e1', 'family', 'guy', 'plays', 'regular_tv_appearance', 'tv', 'tv_character', 'voice']
# words ['e1', 'education', 'institution', 'people', 'person', 'school', 'went']
# words ['actor', 'appeared_in_tv_program', 'e1', 'family', 'guy', 'regular_tv_appearance', 'speaks', 'tv', 'tv_character']
# words ['did', 'e1', 'hit', 'location', 'sports', 'sports_team', 'tornado']
# words ['base', 'continent', 'countries', 'e1', 'locations', 'map', 'world']
# words ['e1', 'invented', 'leadership', 'organization', 'person']
# words ['did', 'e1', 'location_of_ceremony', 'marriage', 'people', 'person', 'represent', 'spouse_s', 'state']
# words ['business', 'driving', 'e1', 'sponsored_by', 'sponsored_recipient', 'sponsorship']
# words ['composer', 'compositions', 'does', 'e1', 'music', 'sing', 'songs']
# words ['containedby', 'e1', 'location']
# words ['came', 'did', 'draft', 'drafted', 'drafted_athlete', 'e1', 'nba', 'sports', 'sports_league_draft_pick', 'year']
# words ['contains', 'countries', 'e1', 'fall', 'location']
# words ['country', 'e1', 'nationality', 'people', 'person']
# words ['containedby', 'e1', 'location', 'texas']
# words ['country', 'currency', 'currency_used', 'e1', 'location']
# words ['does', 'e1', 'position', 'pro_athlete', 'sports', 'sports_team_roster', 'teams']
# words ['current_team', 'does', 'e1', 'football_player', 'play', 'soccer', 'sports', 'sports_team_roster', 'team']
# words ['called', 'e1', 'parents', 'people', 'person']
# words ['americans', 'did', 'e1', 'ethnicity', 'included_in_group', 'live', 'native', 'people']
# words ['called', 'e1', 'location', 'partially_contains', 'rainforest']
# words ['containedby', 'e1', 'location', 'ne']
# words ['country', 'e1', 'language', 'location', 'official_language']
# words ['e1', 'people', 'person', 'profession', 'trained']
# words ['basketball', 'basketball_player', 'basketball_player_stats', 'e1', 'played', 'player_statistics', 'team']
# words ['art_subject', 'artwork_on_the_subject', 'e1', 'visit', 'visual_art']
# words ['american_football', 'e1', 'football_player', 'played', 'player_rushing_statistics', 'rushing', 'team']
# words ['e1', 'kids', 'tourist_attractions', 'travel', 'travel_destination']
# words ['does', 'e1', 'live', 'people', 'person', 'place_of_birth']
# words ['county', 'e1', 'hud_county_place', 'location', 'texas']
# words ['country', 'e1', 'language', 'location', 'main', 'official_language', 'spoken']
# words ['does', 'e1', 'leadership', 'organization', 'play', 'role', 'soccer']
# words ['cvg', 'e1', 'game_character', 'game_performance', 'games', 'play', 'voice_actor']
# words ['basketball', 'basketball_historical_roster_position', 'did', 'e1', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['base', 'continent', 'countries', 'e1', 'located', 'locations']
# words ['born', 'e1', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['argumentmaps', 'base', 'did', 'e1', 'innovator', 'invent', 'original_ideas']
# words ['e1', 'known', 'people', 'person', 'profession']
# words ['did', 'died', 'e1', 'live', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['e1', 'noble_person', 'noble_title', 'noble_title_tenure', 'royalty', 'titles']
# words ['e1', 'ethnicity', 'indians', 'language', 'languages_spoken', 'people', 'speak']
# words ['business', 'channel', 'come', 'company', 'does', 'e1', 'employment_history', 'employment_tenure', 'people', 'person']
# words ['did', 'e1', 'job', 'people', 'person', 'profession']
# words ['base', 'context_name', 'e1', 'language', 'schemastaging', 'short_name']
# words ['e1', 'fantasy_football', 'nfl', 'nfl_team', 'player', 'szaijan', 'user']
# words ['college', 'did', 'e1', 'education', 'institution', 'people', 'person']
# words ['biome', 'category', 'e1', 'geographical_feature', 'geography', 'kind']
# words ['american_football', 'did', 'e1', 'football_historical_roster_position', 'football_player', 'former_teams', 'retire', 'team']
# words ['administrative_division', 'countries', 'e1', 'first_level_division_of', 'located', 'location']
# words ['containedby', 'e1', 'located', 'location', 'province']
# words ['basketball', 'basketball_historical_roster_position', 'e1', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['american_football', 'does', 'e1', 'football_player', 'play', 'position', 'position_s']
# words ['containedby', 'e1', 'location']
# words ['athlete_extra', 'athlete_salary', 'base', 'does', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['containedby', 'e1', 'location']
# words ['american_football', 'did', 'e1', 'football_historical_roster_position', 'football_player', 'former_teams', 'position_s']
# words ['american_football', 'current_team_head_coached', 'did', 'e1', 'football_coach']
# words ['american_football', 'did', 'e1', 'football_player', 'games', 'leave', 'player_game_statistics', 'season', 'usc']
# words ['come', 'e1', 'earthquake', 'earthquake_nearest_location', 'earthquakes', 'location', 'nearest_location', 'people', 'robert', 'user']
# words ['e1', 'griffin', 'plays', 'program_creator', 'stewie', 'tv', 'tv_program']
# words ['baseball', 'baseball_team', 'current_manager', 'e1', 'manager']
# words ['did', 'e1', 'live', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['countries', 'e1', 'export', 'exported_to', 'imports_and_exports', 'location', 'places_exported_to', 'statistical_region']
# words ['artist', 'did', 'e1', 'grow', 'music', 'origin']
# words ['actor', 'appeared_in_tv_program', 'e1', 'regular_tv_appearance', 'tv', 'tv_character', 'voice']
# words ['e1', 'inventions', 'inventor', 'law']
# words ['actor', 'did', 'e1', 'film', 'movies', 'performance', 'star']
# words ['did', 'e1', 'election_campaigns', 'government', 'politician', 'president', 'run']
# words ['country', 'currency', 'currency_used', 'e1', 'location']
# words ['containedby', 'did', 'e1', 'location', 'originate']
# words ['does', 'e1', 'live', 'location', 'people', 'person', 'place_lived', 'places_lived']
# words ['actor', 'appeared_in_tv_program', 'does', 'e1', 'family', 'guy', 'regular_tv_appearance', 'tv', 'tv_character', 'voice']
# words ['deceased_person', 'did', 'e1', 'got', 'people', 'place_of_death', 'shot']
# words ['currency', 'dated_money_value', 'does', 'e1', 'foreign_direct_investment_net_inflows', 'location', 'measurement_unit', 'statistical_region', 'type']
# words ['dogtown', 'e1', 'film', 'films', 'lords', 'person_or_entity_appearing_in_film', 'personal_film_appearance', 'plays', 'type_of_appearance']
# words ['award', 'award_honor', 'award_winner', 'awards_won', 'contribution', 'did', 'dna', 'e1', 'make']
# words ['award', 'award_honor', 'award_winner', 'award_winning_work', 'awards_won', 'e1', 'speaks', 'stewie']
# words ['administrative_division', 'administrative_division_capital_relationship', 'capital', 'city', 'e1', 'location', 'usa']
# words ['country', 'does', 'e1', 'languages_spoken', 'location', 'people', 'speak']
# words ['countries', 'default_domain', 'e1', 'international_organization', 'ktrueman', 'member_states', 'user']
# words ['e1', 'government', 'government_position_held', 'government_positions_held', 'known', 'office_position_or_title', 'politician', 'president']
# words ['country', 'e1', 'language', 'languages_spoken', 'location', 'speak']
# words ['cause_of_death', 'deceased_person', 'did', 'died', 'e1', 'illness', 'people']
# words ['did', 'e1', 'former_team_s', 'hockey_player', 'ice_hockey', 'play', 'sports', 'sports_team_roster', 'team']
# words ['come', 'country', 'deceased_person', 'did', 'e1', 'people', 'place_of_death']
# words ['actor', 'e1', 'film', 'movies', 'performance']
# words ['base', 'celebrity', 'e1', 'popstra', 'religion', 'religion_choice']
# words ['baseball', 'baseball_roster_position', 'did', 'e1', 'play', 'pro_athlete', 'sports', 'team', 'teams']
# words ['candidate', 'did', 'e1', 'president', 'presidential_campaigns', 'robert', 'run', 'user', 'x2008_presidential_election', 'year']
# words ['country', 'e1', 'language', 'local', 'location', 'official_language']
# words ['country', 'e1', 'form_of_government', 'government', 'location', 'structure']
# words ['adjoin_s', 'adjoining_relationship', 'adjoins', 'country', 'e1', 'location', 'surrounds']
# words ['country', 'e1', 'languages', 'location', 'official_language', 'primary']
# words ['2011', 'american_football', 'e1', 'football_historical_roster_position', 'football_player', 'former_teams', 'play', 'team']
# words ['e1', 'people', 'person', 'sibling', 'sibling_relationship', 'sibling_s', 'siblings']
# words ['citytown', 'e1', 'headquarters', 'location', 'mailing_address', 'organization']
# words ['e1', 'government', 'government_position_held', 'governmental_body', 'member', 'members', 'office_holder']
# words ['district_represented', 'e1', 'government', 'government_position_held', 'government_positions_held', 'politician', 'state']
# words ['citytown', 'default_domain', 'e1', 'headquarters', 'international_organization', 'ktrueman', 'location', 'mailing_address', 'main', 'user']
# words ['e1', 'old', 'previously_known_as', 'sports', 'sports_team']
# words ['does', 'e1', 'play', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['e1', 'football', 'owner_s', 'owns', 'professional_sports_team', 'sports', 'team']
# words ['2009', 'does', 'e1', 'play', 'pro_athlete', 'sports', 'sports_team_roster', 'team', 'teams']
# words ['e1', 'form', 'founders', 'helped', 'organization']
# words ['2013', 'business', 'drive', 'e1', 'sponsored_by', 'sponsored_recipient', 'sponsorship']
# words ['athlete_extra', 'athlete_salary', 'base', 'does', 'e1', 'play', 'salary', 'schemastaging', 'team']
# words ['actor', 'appeared_in_tv_program', 'e1', 'looney', 'plays', 'regular_tv_appearance', 'tunes', 'tv', 'tv_character']
# words ['country', 'currency', 'currency_used', 'e1', 'location']
# words ['containedby', 'e1', 'location']
# words ['e1', 'government', 'government_position_held', 'jurisdiction_of_office', 'lucie', 'map', 'political_district', 'port', 'representatives', 'st']
# words ['basketball', 'basketball_player', 'basketball_roster_position', 'does', 'e1', 'play', 'team']
# words ['art', 'associated_periods_or_movements', 'did', 'e1', 'style', 'use', 'visual_art', 'visual_artist']
# words ['country', 'current', 'e1', 'form_of_government', 'government', 'location']
# words ['e1', 'human_language', 'language', 'main_country', 'used']
# words ['country', 'does', 'e1', 'language', 'location', 'official_language', 'people', 'speak']
# words ['does', 'e1', 'geography', 'origin', 'river', 'start']
# words ['does', 'e1', 'live', 'people', 'person', 'place_of_birth']
# words ['e1', 'government', 'government_position_held', 'government_positions_held', 'happened', 'jail', 'office_position_or_title', 'politician', 'released']
# words ['e1', 'location', 'london', 'time', 'time_zones', 'zone']
# words ['2010', 'country', 'currency', 'dated_money_value', 'e1', 'gdp_nominal', 'location', 'measurement_unit']
# words ['country', 'currency_used', 'e1', 'kind', 'location', 'money', 'use']
# words ['bones', 'city', 'e1', 'parents', 'people', 'person', 'play']
# words ['2011', 'basketball', 'basketball_player', 'basketball_player_stats', 'does', 'e1', 'play', 'player_statistics', 'team']
# words ['baseball', 'baseball_player', 'did', 'e1', 'former_teams', 'play', 'professional', 'sports', 'sports_team_roster', 'team']
# words ['country', 'e1', 'language', 'languages_spoken', 'location', 'use']
# words ['address', 'architecture', 'e1', 'located', 'location', 'mailing_address', 'state_province_region', 'structure']

# %%
n_clusters=3
number_of_seeds_to_try=10
max_iter = 300
number_of_process=2 # seads are distributed
model = KMeans(n_clusters=n_clusters, max_iter=max_iter, n_init=number_of_seeds_to_try, n_jobs=number_of_process).fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-6482a345e960> in <module>
#       3 max_iter = 300
#       4 number_of_process=2 # seads are distributed
# ----> 5 model = KMeans(n_clusters=n_clusters, max_iter=max_iter, n_init=number_of_seeds_to_try, n_jobs=number_of_process).fit(X)
#
# c:\users\jvret\appdata\local\programs\python\python37\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     970                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     971                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 972                 return_n_iter=True)
#     973         return self
#     974
#
# c:\users\jvret\appdata\local\programs\python\python37\lib\site-packages\sklearn\cluster\k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     314     if _num_samples(X) < n_clusters:
#     315         raise ValueError("n_samples=%d should be >= n_clusters=%d" % (
# --> 316             _num_samples(X), n_clusters))
#     317
#     318     tol = _tolerance(X, tol)
#
# ValueError: n_samples=1 should be >= n_clusters=3
